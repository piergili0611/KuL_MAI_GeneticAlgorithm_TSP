# %%
from Implement_pygad import *
from r0818807 import *
# Out:
# c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\numba\core\decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)

# %%
# Create an instance of the r0818807 class
c = r0818807()

# Define the filename for the dataset
filename = 'tour750.csv'

distanceMatrix = c.creatAndGet_distnace_matrix(filename)

GA = GA_pyGad(distance_matrix=distanceMatrix)
GA.run()
# Out:
# c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\pygad\pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# Best distance: 6381837.941359277
# c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\pygad\visualize\plot.py:109: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   matplotlib.pyplot.legend()
